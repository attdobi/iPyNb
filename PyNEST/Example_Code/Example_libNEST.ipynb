# %% [markdown]
# <h1> Example header to load in libNEST </h1>

# %%
from __future__ import division
import sys
sys.path.insert(2,'/global/projecta/projectdirs/lux/Tools/fastNEST/libNEST') #add to import Lib-NEST
import libNEST

#Need to add this to make Skin Response maps load in... Doesn't matter for LUX detector
import os
os.environ['NESTPATH']='/global/projecta/projectdirs/lux/Tools/fastNEST/libNEST/'
os.environ['NESTDATA']='/global/projecta/projectdirs/lux/Tools/fastNEST/LCEAndEFieldMaps/'

# %pylab inline
pylab.rcParams['figure.figsize'] = (10.0, 8.0) # set size of figures"
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# <h1> Easier way to start, simply import pyNEST </h1>

# %%
from __future__ import division
import sys
home_dir=!echo "$HOME"
sys.path.insert(2,home_dir[0]+'/iPyNb/NERSC_Import')#point to iPyNb in $HOME directory
from pyNEST import *
# %pylab inline
pylab.rcParams['figure.figsize'] = (10.0, 8.0) # set size of figures"
plt.rcParams.update({'font.size': 24})
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# <h1> Example code </h1>

# %%
NEST=libNEST.NEST(0,10,-1,2.88,-1) #PT, Energy, EField, density, dT
myDet=libNEST.Detector()
myDet.LZSettings()
NEST.SetDetectorParameters(myDet)
print('Energy, S1c, S2c, DriftLocation(us), ElectricField (V/cm)')
for En in arange(1,10,1):
    NEST.SetEnergy(En)
    NEST.DetectorResponse()
    print(NEST.GetS1c(),NEST.GetS2c(),NEST.GetS2(), NEST.GetDriftLocation(), NEST.GetElectricField())
    #NEST.SetDriftLocation(100)
    #NEST.SetElectricField(100)
# Out:
# Energy, S1c, S2c, DriftLocation(us), ElectricField (V/cm)
# (0.0, 763.8682775432524, 529.3743341029839, 309.1277250307612, 290.0)
# (0.0, 1027.83230479242, 874.7346224788294, 135.96473304354586, 290.0)
# (0.0, 1796.181148264779, 1121.199272521907, 397.27549753133206, 290.0)
# (0.0, 1991.7465792318712, 1623.9492078261387, 172.09926478224807, 290.0)
# (4.019259188387392, 2309.3581516292215, 1259.2002547350608, 511.2734544312116, 290.0)
# (0.0, 3620.6186413902465, 2368.4860574200497, 357.76409981199544, 290.0)
# (0.0, 4560.952341933556, 3338.6351405379505, 262.9901753030252, 290.0)
# (4.7805247695854485, 4855.56634019179, 3311.5082230532466, 322.6346491480712, 290.0)
# (3.585195087215434, 6065.031237730874, 5371.971661392898, 102.29357322361321, 290.0)

# %% [markdown]
# <h1> Test the skin response function </h1>

# %%
NEST=libNEST.NEST(1,10,-1,2.88,-1) #PT, Energy, EField, density, dT
myDet=libNEST.Detector()
myDet.LZSettings()
NEST.SetDetectorParameters(myDet)
print('Energy, S1c, S2c, DriftLocation(us), ElectricField (V/cm)')
for En in arange(500,550,1):
    NEST.SetEnergy(En)
    NEST.DetectorResponse()
    print(NEST.GetS1c(),NEST.GetS2c(), NEST.GetDriftLocation(), NEST.GetElectricField())
    NEST.SkinResponse(77,60)
    print(NEST.GetEnergy(), NEST.GetS1(), NEST.GetSkinLCE(), NEST.GetSkinEField())
    #NEST.SetDriftLocation(100)
    #NEST.SetElectricField(100)
# Out:
# Energy, S1c, S2c, DriftLocation(us), ElectricField (V/cm)
# (1342.6800841357067, 1434511.224198298, 814.5938825126271, 290.0)
# (500.0, 28.259504127081748, 0.0016694474999999999, 6278.475)
# (1219.685964208946, 1609299.440916829, 287.53783901501447, 290.0)
# (501.0, 17.669289737626606, 0.0016694474999999999, 6278.475)
# (972.5574642728025, 1818404.2454365992, 64.66522018802353, 290.0)
# (502.0, 9.782395898900122, 0.0016694474999999999, 6278.475)
# (911.5521563477112, 1961541.4506523544, 544.6191045890097, 290.0)
# (503.0, 12.686178860897666, 0.0016694474999999999, 6278.475)
# (1325.2255717289618, 1460200.7727894068, 731.8746412902605, 290.0)
# (504.0, 10.880784986504116, 0.0016694474999999999, 6278.475)
# (936.1041243248536, 1937338.7775986176, 278.10422009346075, 290.0)
# (505.0, 13.741823665941592, 0.0016694474999999999, 6278.475)
# (1363.2637220616296, 1414180.017053567, 519.8455333667341, 290.0)
# (506.0, 16.444378659909955, 0.0016694474999999999, 6278.475)
