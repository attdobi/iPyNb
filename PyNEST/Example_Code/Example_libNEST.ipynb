# %% [markdown]
# <h1> Example header to load in libNEST </h1>

# %%
from __future__ import division
import sys
home_dir=!echo "$HOME"
sys.path.insert(2,home_dir[0]+'/iPyNb/NERSC_Import') 
sys.path.insert(2,home_dir[0]+'/LZ_git/fastNEST/libNEST') #add to import Lib-NEST
import libNEST

#Need to add this to make Skin Response maps load in
import os
os.environ['NESTPATH']='/global/homes/a/adobi/LZ_git/fastNEST/libNEST/'
os.environ['NESTDATA']='/global/homes/a/adobi/LZ_git/fastNEST/LCEAndEFieldMaps/'
#import pyROOT_import
#from ROOT import TH2D

# %pylab inline
pylab.rcParams['figure.figsize'] = (10.0, 8.0) # set size of figures"
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# <h1> Easier way to start, simply import pyNEST </h1>

# %%
from __future__ import division
import sys
home_dir=!echo "$HOME"
sys.path.insert(2,home_dir[0]+'/iPyNb/NERSC_Import') 
from pyNEST import *
# %pylab inline
pylab.rcParams['figure.figsize'] = (10.0, 8.0) # set size of figures"
plt.rcParams.update({'font.size': 24})
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['pylab']
# `%matplotlib` prevents importing * from pylab and numpy

# %% [markdown]
# <h1> Example code </h1>

# %%
NEST=libNEST.NEST(0,10,-1,2.88,-1) #PT, Energy, EField, density, dT
myDet=libNEST.Detector()
myDet.LZSettings()
NEST.SetDetectorParameters(myDet)
print('Energy, S1c, S2c, DriftLocation(us), ElectricField (V/cm)')
for En in arange(1,10,1):
    NEST.SetEnergy(En)
    NEST.DetectorResponse()
    print(NEST.GetS1c(),NEST.GetS2c(),NEST.GetS2(), NEST.GetDriftLocation(), NEST.GetElectricField())
    #NEST.SetDriftLocation(100)
    #NEST.SetElectricField(100)
# Out:
# Energy, S1c, S2c, DriftLocation(us), ElectricField (V/cm)
# (0.0, 411.9862181444509, 364.9472604635905, 102.20283013405279, 290.0)
# (0.0, 1338.8364693618764, 864.0919643509962, 369.1303160086274, 290.0)
# (0.0, 1201.5366750377825, 924.7401096260892, 220.73436016999185, 290.0)
# (1.6739956109206457, 2512.6591046337194, 2318.63591510217, 67.74563089637086, 290.0)
# (4.470028178408551, 2789.667368642552, 1238.2284602051204, 684.7188839958515, 290.0)
# (0.0, 3843.417934742642, 3472.114153492534, 85.64743713187053, 290.0)
# (9.086386172536086, 3975.314075648286, 2844.6716692515456, 282.11509486832654, 290.0)
# (3.9289621737147797, 5339.537330490901, 2713.1029532844154, 570.749799832562, 290.0)
# (7.550556306567014, 4731.808362553611, 2256.2522302620105, 624.3277519861701, 290.0)

# %% [markdown]
# <h1> Test the skin response function </h1>

# %%
NEST=libNEST.NEST(1,10,-1,2.88,-1) #PT, Energy, EField, density, dT
myDet=libNEST.Detector()
myDet.LZSettings()
NEST.SetDetectorParameters(myDet)
print('Energy, S1c, S2c, DriftLocation(us), ElectricField (V/cm)')
for En in arange(500,550,1):
    NEST.SetEnergy(En)
    NEST.DetectorResponse()
    print(NEST.GetS1c(),NEST.GetS2c(), NEST.GetDriftLocation(), NEST.GetElectricField())
    NEST.SkinResponse(77,60)
    print(NEST.GetEnergy(), NEST.GetS1(), NEST.GetSkinLCE(), NEST.GetSkinEField())
    #NEST.SetDriftLocation(100)
    #NEST.SetElectricField(100)
# Out:
# Energy, S1c, S2c, DriftLocation(us), ElectricField (V/cm)
# (1220.7459346515052, 1434265.8195584763, 442.244405733468, 290.0)
# (500.0, 33.59656365331776, 0.00177452, 5024.025)
# (1555.713192032959, 1273504.1319138757, 303.7101077006664, 290.0)
# (501.0, 14.947825293191029, 0.00177452, 5024.025)
# (927.3283550537163, 1918309.5921816907, 709.3874804312363, 290.0)
# (502.0, 24.44599295639472, 0.00177452, 5024.025)
# (1123.644668616075, 1681345.5949342914, 538.3845166638959, 290.0)
# (503.0, 18.410454818811353, 0.00177452, 5024.025)
# (919.6317254445644, 1963168.7822835243, 657.7250721866264, 290.0)
# (504.0, 13.285189390867004, 0.00177452, 5024.025)
# (1062.714161935131, 1677078.5226580217, 815.7978779924102, 290.0)
# (505.0, 16.239685785878258, 0.00177452, 5024.025)
