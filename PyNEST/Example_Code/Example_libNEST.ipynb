# %% [markdown]
# <h1> Example header to load in libNEST </h1>

# %%
from __future__ import division
import sys
home_dir=!echo "$HOME"
sys.path.insert(2,home_dir[0]+'/iPyNb/NERSC_Import') 
sys.path.insert(2,home_dir[0]+'/LZ_git/fastNEST/libNEST') #add to import Lib-NEST
import libNEST

#Need to add this to make Skin Response maps load in
import os
os.environ['NESTPATH']='/global/homes/a/adobi/LZ_git/fastNEST/libNEST/'
os.environ['NESTDATA']='/global/homes/a/adobi/LZ_git/fastNEST/LCEAndEFieldMaps/'
#import pyROOT_import
#from ROOT import TH2D

# %pylab inline
pylab.rcParams['figure.figsize'] = (10.0, 8.0) # set size of figures"
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# <h1> Easier way to start, simply import pyNEST </h1>

# %%
from __future__ import division
import sys
home_dir=!echo "$HOME"
sys.path.insert(2,home_dir[0]+'/iPyNb/NERSC_Import') 
from pyNEST import *
# %pylab inline
pylab.rcParams['figure.figsize'] = (10.0, 8.0) # set size of figures"
plt.rcParams.update({'font.size': 24})
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['pylab']
# `%matplotlib` prevents importing * from pylab and numpy

# %% [markdown]
# <h1> Example code </h1>

# %%
NEST=libNEST.NEST(0,10,-1,2.88,-1) #PT, Energy, EField, density, dT
myDet=libNEST.Detector()
myDet.LZSettings()
NEST.SetDetectorParameters(myDet)
print('Energy, S1c, S2c, DriftLocation(us), ElectricField (V/cm)')
for En in arange(1,10,1):
    NEST.SetEnergy(En)
    NEST.DetectorResponse()
    print(NEST.GetS1c(),NEST.GetS2c(),NEST.GetS2(), NEST.GetDriftLocation(), NEST.GetElectricField())
    #NEST.SetDriftLocation(100)
    #NEST.SetElectricField(100)
# Out:
# Energy, S1c, S2c, DriftLocation(us), ElectricField (V/cm)
# (0.0, 764.6822185243356, 453.5020354708894, 440.4342765250709, 290.0)
# (0.0, 1854.0366291268274, 907.3601187341956, 602.3918568626046, 290.0)
# (0.0, 1736.332637613903, 1041.0034396746407, 431.2704674356617, 290.0)
# (0.0, 2196.0868665715257, 1976.9262185465445, 88.62784061226994, 290.0)
# (0.0, 3172.227295167225, 1249.9841540695547, 785.0884993501007, 290.0)
# (0.0, 3858.56536324789, 2187.8751018796647, 478.2883975427598, 290.0)
# (2.5562065183129503, 4330.483544639495, 2848.5437899553303, 353.10850261105224, 290.0)
# (3.57686276030564, 4912.9310573874145, 3514.272327524215, 282.4372327473946, 290.0)
# (0.0, 5762.526434167502, 2389.6481928056887, 742.0337552387267, 290.0)

# %% [markdown]
# <h1> Test the skin response function </h1>

# %%
NEST=libNEST.NEST(1,10,-1,2.88,-1) #PT, Energy, EField, density, dT
myDet=libNEST.Detector()
myDet.LZSettings()
NEST.SetDetectorParameters(myDet)
print('Energy, S1c, S2c, DriftLocation(us), ElectricField (V/cm)')
for En in arange(500,550,1):
    NEST.SetEnergy(En)
    NEST.DetectorResponse()
    print(NEST.GetS1c(),NEST.GetS2c(), NEST.GetDriftLocation(), NEST.GetElectricField())
    NEST.SkinResponse(77,60)
    print(NEST.GetEnergy(), NEST.GetS1(), NEST.GetSkinLCE(), NEST.GetSkinEField())
    #NEST.SetDriftLocation(100)
    #NEST.SetElectricField(100)
# Out:
# Energy, S1c, S2c, DriftLocation(us), ElectricField (V/cm)
# (1054.0845590883432, 1793809.1059532596, 294.07102596969344, 290.0)
# (500.0, 8.607014880329357, 0.00177452, 5024.025)
# (1228.8749757523024, 1627535.0185517524, 62.21156636304222, 290.0)
# (501.0, 36.56571731946832, 0.00177452, 5024.025)
# (1140.821584286119, 1600580.382648181, 266.54049206115303, 290.0)
# (502.0, 14.129386110098954, 0.00177452, 5024.025)
# (1218.5974920200392, 1628736.9602333263, 384.9960805486422, 290.0)
# (503.0, 24.000058492756043, 0.00177452, 5024.025)
# (1143.314856474242, 1679076.3471126482, 257.2533736478537, 290.0)
# (504.0, 21.29156847228611, 0.00177452, 5024.025)
# (1225.1198696259764, 1623642.1074196608, 493.45985898198563, 290.0)
# (505.0, 15.954490924626578, 0.00177452, 5024.025)
