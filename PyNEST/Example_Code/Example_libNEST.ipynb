# %% [markdown]
# <h1> Example header to load in libNEST </h1>

# %%
from __future__ import division
import sys
home_dir=!echo "$HOME"
sys.path.insert(2,home_dir[0]+'/iPyNb/NERSC_Import') 
sys.path.insert(2,home_dir[0]+'/LZ_git/fastNEST/libNEST') #add to import Lib-NEST
import libNEST

#Need to add this to make Skin Response maps load in
import os
os.environ['NESTPATH']='/global/homes/a/adobi/LZ_git/fastNEST/libNEST/'
os.environ['NESTDATA']='/global/homes/a/adobi/LZ_git/fastNEST/LCEAndEFieldMaps/'
#import pyROOT_import
#from ROOT import TH2D

# %pylab inline
pylab.rcParams['figure.figsize'] = (10.0, 8.0) # set size of figures"
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# <h1> Easier way to start, simply import pyNEST </h1>

# %%
from __future__ import division
import sys
home_dir=!echo "$HOME"
sys.path.insert(2,home_dir[0]+'/iPyNb/NERSC_Import') 
from pyNEST import *
# %pylab inline
pylab.rcParams['figure.figsize'] = (10.0, 8.0) # set size of figures"
plt.rcParams.update({'font.size': 24})
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['pylab']
# `%matplotlib` prevents importing * from pylab and numpy

# %% [markdown]
# <h1> Example code </h1>

# %%
NEST=libNEST.NEST(0,10,-1,2.88,-1) #PT, Energy, EField, density, dT
myDet=libNEST.Detector()
myDet.LZSettings()
NEST.SetDetectorParameters(myDet)
print('Energy, S1c, S2c, DriftLocation(us), ElectricField (V/cm)')
for En in arange(1,10,1):
    NEST.SetEnergy(En)
    NEST.DetectorResponse()
    print(NEST.GetS1c(),NEST.GetS2c(),NEST.GetS2(), NEST.GetDriftLocation(), NEST.GetElectricField())
    #NEST.SetDriftLocation(100)
    #NEST.SetElectricField(100)
# Out:
# Energy, S1c, S2c, DriftLocation(us), ElectricField (V/cm)
# (0.0, 484.2794472937126, 442.96650095352277, 75.16859194338322, 290.0)
# (0.0, 1915.5685977385672, 758.3942174046219, 781.0955167101231, 290.0)
# (0.0, 2488.241556621966, 1075.3392715467162, 707.2264584507327, 290.0)
# (3.534896991940411, 3044.5106365167467, 1369.7245206613477, 673.3298434762285, 290.0)
# (0.0, 2315.340917661934, 1565.3301646986304, 330.0009247806389, 290.0)
# (0.0, 4186.8747834245305, 2059.5013013043304, 598.1006717375014, 290.0)
# (2.556663702122591, 3269.306543447372, 1638.3978575125184, 582.3941774676089, 290.0)
# (0.0, 4613.935757591155, 2367.9930728985278, 562.313408770645, 290.0)
# (4.022575589671122, 4373.120257649668, 1980.176530158702, 667.9011230795644, 290.0)

# %% [markdown]
# <h1> Test the skin response function </h1>

# %%
NEST=libNEST.NEST(1,10,-1,2.88,-1) #PT, Energy, EField, density, dT
myDet=libNEST.Detector()
myDet.LZSettings()
NEST.SetDetectorParameters(myDet)
print('Energy, S1c, S2c, DriftLocation(us), ElectricField (V/cm)')
for En in arange(500,550,1):
    NEST.SetEnergy(En)
    NEST.DetectorResponse()
    print(NEST.GetS1c(),NEST.GetS2c(), NEST.GetDriftLocation(), NEST.GetElectricField())
    NEST.SkinResponse(77,60)
    print(NEST.GetEnergy(), NEST.GetS1(), NEST.GetSkinLCE(), NEST.GetSkinEField())
    #NEST.SetDriftLocation(100)
    #NEST.SetElectricField(100)
# Out:
# Energy, S1c, S2c, DriftLocation(us), ElectricField (V/cm)
# (1210.0481315382408, 1620811.0950134846, 620.5102419493254, 290.0)
# (500.0, 15.173510551076482, 0.002134375, 6278.475)
# (1096.7221777861157, 1717411.935206895, 284.1217419740278, 290.0)
# (501.0, 12.449080707492493, 0.002134375, 6278.475)
# (1235.3014358184541, 1510183.0713580556, 811.3479716450441, 290.0)
# (502.0, 15.198754828756446, 0.002134375, 6278.475)
# (1122.4646715355793, 1660490.7425077115, 360.2271011367906, 290.0)
# (503.0, 27.153585362337765, 0.002134375, 6278.475)
# (1162.0283889458497, 1675631.887045572, 279.9443608372938, 290.0)
# (504.0, 15.277844729165889, 0.002134375, 6278.475)
# (1124.18878773357, 1725316.5424995553, 693.0622191774194, 290.0)
# (505.0, 14.711788458072881, 0.002134375, 6278.475)
