# %%
from __future__ import division
import sys
home_dir=!echo "$HOME"
sys.path.insert(2,home_dir[0]+'/iPyNb/NERSC_Import') 
sys.path.insert(2,home_dir[0]+'/LZ_git/fastNEST/libNEST') #add to import Lib-NEST
import libNEST
from pyROOT_import import *
from LZlim_pyNEST import *
from ROOT import TH2D
# %pylab inline
pylab.rcParams['figure.figsize'] = (10.0, 8.0) # set size of figures"

#FYI, you don't need ROOT to run this
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['pylab']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
NEST=libNEST.NEST(0,10,-1,2.88,-1) #PT, Energy, EField, density, dT
myDet=libNEST.Detector()
myDet.LZSettings()
NEST.SetDetectorParameters(myDet)
print('Energy, S1c, S2c, DriftLocation(us), ElectricField (V/cm)')
for En in arange(1,10,1):
    NEST.SetEnergy(En)
    NEST.DetectorResponse()
    print(NEST.GetS1c(),NEST.GetS2c(),NEST.GetS2(), NEST.GetDriftLocation(), NEST.GetElectricField())
    #NEST.SetDriftLocation(100)
    #NEST.SetElectricField(100)
# Out:
# Energy, S1c, S2c, DriftLocation(us), ElectricField (V/cm)
# (0.0, 0.0, 0.0, 662.3385132120923, 290.0)
# (0.0, 1258.445079823109, 768.124976086197, 416.1720082103275, 290.0)
# (0.0, 1526.672277693886, 1336.948220200898, 111.8667876967229, 290.0)
# (3.1502174960425244, 2449.9014343272906, 1059.7719033627773, 706.4290207354352, 290.0)
# (4.804918768115623, 2584.2710375373017, 2148.2474405692524, 155.7789017676376, 290.0)
# (0.0, 3575.459791854552, 2825.630268222183, 198.41045048912054, 290.0)
# (4.091681690935701, 4814.126452195974, 2269.018403695539, 634.1107453998644, 290.0)
# (2.0927624018897384, 4608.186288924075, 3587.9441948134236, 210.96493049575946, 290.0)
# (0.0, 5236.948074383345, 3626.52949303487, 309.7711165179033, 290.0)

# %% [markdown]
# <h1> Test the skin response function </h1>

# %%
myDet.cathodeVoltage
# Out:
# 50.0

# %%
NEST=libNEST.NEST(1,10,-1,2.88,-1) #PT, Energy, EField, density, dT
myDet=libNEST.Detector()
myDet.LZSettings()
NEST.SetDetectorParameters(myDet)
print('Energy, S1c, S2c, DriftLocation(us), ElectricField (V/cm)')
for En in arange(500,550,1):
    NEST.SetEnergy(En)
    NEST.DetectorResponse()
    print(NEST.GetS1c(),NEST.GetS2c(), NEST.GetDriftLocation(), NEST.GetElectricField())
    NEST.SkinResponse(77,60)
    print(NEST.GetEnergy(), NEST.GetS1(), NEST.GetSkinLCE(), NEST.GetSkinEField())
    #NEST.SetDriftLocation(100)
    #NEST.SetElectricField(100)
# Out:
# Energy, S1c, S2c, DriftLocation(us), ElectricField (V/cm)
# (1008.6240675581312, 1792499.9918922605, 796.4086088572628, 290.0)
# (500.0, 0.0, 0.0, 0.0)
# (928.6462877081233, 1940511.797455879, 75.61842335304246, 290.0)
# (501.0, 0.0, 0.0, 0.0)
# (1137.5847630937194, 1625795.954618963, 704.3985144875012, 290.0)
# (502.0, 0.0, 0.0, 0.0)
# (949.346749462853, 1871029.619827893, 373.94240962378683, 290.0)
# (503.0, 0.0, 0.0, 0.0)
# (1025.1560931712597, 1780740.515616228, 508.8076723185368, 290.0)
# (504.0, 0.0, 0.0, 0.0)
# (1140.5718143564168, 1679324.792681272, 611.4840387573, 290.0)
# (505.0, 0.0, 0.0, 0.0)
# (1483.5939641969067, 1266047.471039571, 613.7253699628636, 290.0)
# (506.0, 0.0, 0.0, 0.0)
# (1309.0905098194416, 1441819.6505451903, 806.7002879140898, 290.0)
# (507.0, 0.0, 0.0, 0.0)
# (1084.709343272352, 1820340.9887910224, 410.1008262774441, 290.0)
# (508.0, 0.0, 0.0, 0.0)
# (1114.7020318061948, 1776652.8002623504, 596.4192618140485, 290.0)
# (509.0, 0.0, 0.0, 0.0)
# (1135.3228702495662, 1703127.8521376485, 75.2928541470319, 290.0)
# (510.0, 0.0, 0.0, 0.0)
# (1190.470896968892, 1702936.718145045, 332.204385903338, 290.0)
# (511.0, 0.0, 0.0, 0.0)
# (1275.9783774807877, 1572364.752235303, 795.5154331210535, 290.0)
# (512.0, 0.0, 0.0, 0.0)
# (1278.0661815527474, 1551081.5280880264, 136.81168282479047, 290.0)
# (513.0, 0.0, 0.0, 0.0)
# (1396.4473785739767, 1398639.4627029854, 506.8654664393049, 290.0)
# (514.0, 0.0, 0.0, 0.0)
# (1106.859684920656, 1711128.640054745, 126.33230814016423, 290.0)
# (515.0, 0.0, 0.0, 0.0)
# (1070.3054493978962, 1813904.635405139, 77.65160694248043, 290.0)
# (516.0, 0.0, 0.0, 0.0)
# (1155.2212808885636, 1771484.0874730777, 146.2597006997559, 290.0)
# (517.0, 0.0, 0.0, 0.0)
# (1098.3682024828843, 1861696.347668539, 197.30862661274148, 290.0)
# (518.0, 0.0, 0.0, 0.0)
# (1014.0324609439808, 1936789.8619427043, 106.48532878523693, 290.0)
# (519.0, 0.0, 0.0, 0.0)
# (1334.5184497656721, 1623782.6816793878, 234.26434998516925, 290.0)
# (520.0, 0.0, 0.0, 0.0)
# (1410.9468297023564, 1493885.073521791, 506.83328252998183, 290.0)
# (521.0, 0.0, 0.0, 0.0)
# (1004.4490993530836, 1991108.7264418134, 786.6423728676979, 290.0)
# (522.0, 0.0, 0.0, 0.0)
# (1139.6578856779154, 1824043.3973163986, 180.8536931942217, 290.0)
# (523.0, 0.0, 0.0, 0.0)
# (1085.0176494153222, 1856179.6291990369, 204.01631836039013, 290.0)
# (524.0, 0.0, 0.0, 0.0)
# (961.3706889902137, 2054132.3672317427, 217.3188987376634, 290.0)
# (525.0, 0.0, 0.0, 0.0)
# (1208.6121548505912, 1712616.6194646766, 491.81612593485045, 290.0)
# (526.0, 0.0, 0.0, 0.0)
# (1085.5038523358912, 1889763.250742046, 696.9541457285173, 290.0)
# (527.0, 0.0, 0.0, 0.0)
# (1235.7662732054266, 1690874.1273325847, 108.90701572499238, 290.0)
# (528.0, 0.0, 0.0, 0.0)
# (880.5469626669721, 2177360.503151094, 746.9232941073831, 290.0)
# (529.0, 0.0, 0.0, 0.0)
# (1068.773150671546, 1935089.9837676124, 638.7049681505654, 290.0)
# (530.0, 0.0, 0.0, 0.0)
# (1024.1426912326665, 1950706.728473391, 56.13801493938081, 290.0)
# (531.0, 0.0, 0.0, 0.0)
# (1251.8548160723951, 1636883.7147664765, 61.22441883725114, 290.0)
# (532.0, 0.0, 0.0, 0.0)
# (1101.0042851165963, 1871427.7238643963, 477.1159702708479, 290.0)
# (533.0, 0.0, 0.0, 0.0)
# (1361.6888808015028, 1596833.976835742, 265.7517280222848, 290.0)
# (534.0, 0.0, 0.0, 0.0)
# (1336.7744145907393, 1714075.2652960136, 508.2584022805095, 290.0)
# (535.0, 0.0, 0.0, 0.0)
# (1402.9735760633828, 1627803.8046519167, 607.92250588811, 290.0)
# (536.0, 0.0, 0.0, 0.0)
# (1353.8058859683485, 1652196.472902637, 304.3077406967059, 290.0)
# (537.0, 0.0, 0.0, 0.0)
# (1369.4665888995064, 1623732.762813932, 713.4993220680393, 290.0)
# (538.0, 0.0, 0.0, 0.0)
# (1299.7779149696105, 1637747.6543236591, 131.7842517149169, 290.0)
# (539.0, 0.0, 0.0, 0.0)
# (1233.2608887433953, 1789184.45942367, 575.2702315463218, 290.0)
# (540.0, 0.0, 0.0, 0.0)
# (1068.4095038348503, 1980633.8125317243, 253.5676270988304, 290.0)
# (541.0, 0.0, 0.0, 0.0)
# (1522.5495433156602, 1387336.4093206243, 807.8724407509435, 290.0)
# (542.0, 0.0, 0.0, 0.0)
# (1342.1732783300909, 1663948.2728923138, 186.91482429858297, 290.0)
# (543.0, 0.0, 0.0, 0.0)
# (1281.2328916286215, 1798109.4746111154, 334.66271472242664, 290.0)
# (544.0, 0.0, 0.0, 0.0)
# (1369.1179487034344, 1724564.2481550854, 365.02816278254613, 290.0)
# (545.0, 0.0, 0.0, 0.0)
# (1099.310459109707, 2018499.402210406, 200.58862910433672, 290.0)
# (546.0, 0.0, 0.0, 0.0)
# (1156.5632576105488, 1895678.5485404737, 724.4688635393977, 290.0)
# (547.0, 0.0, 0.0, 0.0)
# (1253.6381216075113, 1841050.02236223, 742.9761287914123, 290.0)
# (548.0, 0.0, 0.0, 0.0)
# (1014.7352030586715, 2113925.5046049263, 418.7858882068191, 290.0)
# (549.0, 0.0, 0.0, 0.0)
