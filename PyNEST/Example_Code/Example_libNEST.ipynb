# %% [markdown]
# <h1> Example header to load in libNEST </h1>

# %%
from __future__ import division
import sys
home_dir=!echo "$HOME"
sys.path.insert(2,home_dir[0]+'/iPyNb/NERSC_Import') 
sys.path.insert(2,home_dir[0]+'/LZ_git/fastNEST/libNEST') #add to import Lib-NEST
import libNEST

#Need to add this to make Skin Response maps load in
import os
os.environ['NESTPATH']='/global/homes/a/adobi/LZ_git/fastNEST/libNEST/'
os.environ['NESTDATA']='/global/homes/a/adobi/LZ_git/fastNEST/LCEAndEFieldMaps/'
#import pyROOT_import
#from ROOT import TH2D

# %pylab inline
pylab.rcParams['figure.figsize'] = (10.0, 8.0) # set size of figures"
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# <h1> Easier way to start, simply import pyNEST </h1>

# %%
from __future__ import division
import sys
home_dir=!echo "$HOME"
sys.path.insert(2,home_dir[0]+'/iPyNb/NERSC_Import') 
from pyNEST import *
# %pylab inline
pylab.rcParams['figure.figsize'] = (10.0, 8.0) # set size of figures"
plt.rcParams.update({'font.size': 24})

# %% [markdown]
# <h1> Example code </h1>

# %%
NEST=libNEST.NEST(0,10,-1,2.88,-1) #PT, Energy, EField, density, dT
myDet=libNEST.Detector()
myDet.LZSettings()
NEST.SetDetectorParameters(myDet)
print('Energy, S1c, S2c, DriftLocation(us), ElectricField (V/cm)')
for En in arange(1,10,1):
    NEST.SetEnergy(En)
    NEST.DetectorResponse()
    print(NEST.GetS1c(),NEST.GetS2c(),NEST.GetS2(), NEST.GetDriftLocation(), NEST.GetElectricField())
    #NEST.SetDriftLocation(100)
    #NEST.SetElectricField(100)
# Out:
# Energy, S1c, S2c, DriftLocation(us), ElectricField (V/cm)
# (0.0, 415.73939115580504, 365.8349454753059, 107.7997523822356, 290.0)
# (0.0, 1144.6726019496266, 658.2479128274629, 466.42541763116606, 290.0)
# (0.0, 1286.9252473507024, 765.4334472116897, 437.9965422441252, 290.0)
# (0.0, 2522.3618437809214, 1359.9499213812858, 520.7614170043263, 290.0)
# (0.0, 3017.0935482839727, 2462.152399244747, 171.3465279877186, 290.0)
# (0.0, 4857.661549986753, 3363.814451244566, 309.7869686973747, 290.0)
# (0.0, 3366.08041918387, 1649.5470195751543, 601.2682920062914, 290.0)
# (3.7556594305148585, 4136.830288530433, 2654.024247177788, 374.16790352631364, 290.0)
# (4.640132902304493, 6123.924590871855, 3434.6697434308476, 487.4920526830014, 290.0)

# %% [markdown]
# <h1> Test the skin response function </h1>

# %%
NEST=libNEST.NEST(1,10,-1,2.88,-1) #PT, Energy, EField, density, dT
myDet=libNEST.Detector()
myDet.LZSettings()
NEST.SetDetectorParameters(myDet)
print('Energy, S1c, S2c, DriftLocation(us), ElectricField (V/cm)')
for En in arange(500,550,1):
    NEST.SetEnergy(En)
    NEST.DetectorResponse()
    print(NEST.GetS1c(),NEST.GetS2c(), NEST.GetDriftLocation(), NEST.GetElectricField())
    NEST.SkinResponse(77,60)
    print(NEST.GetEnergy(), NEST.GetS1(), NEST.GetSkinLCE(), NEST.GetSkinEField())
    #NEST.SetDriftLocation(100)
    #NEST.SetElectricField(100)
# Out:
# Energy, S1c, S2c, DriftLocation(us), ElectricField (V/cm)
# (1162.9582640715591, 1699812.4771447105, 695.6828409626148, 290.0)
# (500.0, 6.039923015078629, 0.00177452, 5024.025)
# (1156.0994983059825, 1658218.1066815462, 456.0674591306597, 290.0)
# (501.0, 27.183085407860137, 0.00177452, 5024.025)
# (1249.2402177525066, 1576959.5783340058, 490.0983288376592, 290.0)
# (502.0, 19.105165277658735, 0.00177452, 5024.025)
# (1379.9877996467499, 1372823.400728518, 65.19433684581891, 290.0)
# (503.0, 6.02555328630116, 0.00177452, 5024.025)
# (906.4652789917343, 1928316.164016982, 484.2546853840351, 290.0)
# (504.0, 22.709968369570348, 0.00177452, 5024.025)
# (1209.3944542736392, 1615037.7691286432, 327.389938261034, 290.0)
# (505.0, 17.348669084127856, 0.00177452, 5024.025)
