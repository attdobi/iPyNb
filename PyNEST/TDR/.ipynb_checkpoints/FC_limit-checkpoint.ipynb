# %% [markdown]
# <h1> Generate F.C. limit </h1>

# %%
from __future__ import division
import sys
home_dir=!echo "$HOME"
sys.path.insert(2,home_dir[0]+'/iPyNb/NERSC_Import') 
from pyROOT_import import *
from pyNEST import *
from ROOT import TH2D
import time
# %pylab inline
pylab.rcParams['figure.figsize'] = (10.0, 8.0) # set size of figures"
plt.rcParams.update({'font.size': 20})
#plt.rc('text', usetex=True)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# TROOT::Append:0: RuntimeWarning: Replacing existing TH1: LCE (Potential memory leak).
# TROOT::Append:0: RuntimeWarning: Replacing existing TH1: EField (Potential memory leak).
# TROOT::Append:0: RuntimeWarning: Replacing existing TH1: LCE (Potential memory leak).
# TROOT::Append:0: RuntimeWarning: Replacing existing TH1: EField (Potential memory leak).
# WARNING: pylab import has clobbered these variables: ['pylab']
# `%matplotlib` prevents importing * from pylab and numpy

# %% [markdown]
# <h1> WS cuts </h1>

# %%
#WS cuts
S1_min=0
S1_max=20
S2raw_min=450
#NS1_coin_req=3

#define. calc LZ  nominal exposure
def calc_exposure(S1_cut, S2_cut, S1_win_max=20):
    LZ_count=sum(S1_cut<S1_win_max)/Det_exposure_factor
    LZ_count_underNr=sum((S1_cut<S1_win_max) & (log10(S2_cut/S1_cut)<sNR(S1_cut)))/Det_exposure_factor
    sig_LZ_count=sqrt(sum(S1_cut<S1_win_max))/Det_exposure_factor
    sig_LZ_count_underNr=sqrt(sum((S1_cut<20) & (log10(S2_cut/S1_cut)<sNR(S1_cut))))/Det_exposure_factor
    print('Count (0 to '+str(S1_win_max) + ' S1) = '+'{:.3f}'.format(LZ_count) + ' +/- ' + '{:.3f}'.format(sig_LZ_count) )
    print('Count below NR mean (0 to '+str(S1_win_max) + ' S1) = '+'{:.3f}'.format(LZ_count_underNr) + ' +/- ' + '{:.3f}'.format(sig_LZ_count_underNr) )

# %% [markdown]
# <h1> Generate ER and NR bands </h1>

# %%
##############################################################################
#Generate Flat ER and 50 GeV WIMP NR spectra:
##############################################################################
#LZ
NEST =NEST_setup(Det='LZ', nFold=3, g1=0.075, custom=True)
S1_bin_cen_n, mean_S2oS1_n, std_S2oS1_n, S1_bin_cen_e, mean_S2oS1_e, std_S2oS1_e, E_bin_cen_e,\
Eff_e, E_bin_cen_n, Eff_n,num_leak_e, num_total_e, leak_gauss_e, sNR = \
genBands(NEST=NEST,S2raw_min=450,nSim=1e6,mWmp=50)

#get NR mean, with a smooth spline
#sNR = ip.UnivariateSpline(S1_bin_cen_n, mean_S2oS1_n,s=.005)

#calculate NR ER discrimination
leak_cut=(S1_bin_cen_e>1) & (S1_bin_cen_e<20)
discrim=100*(1-sum(num_leak_e[leak_cut])/sum(num_total_e[leak_cut]))
discrim
# Out:
# TROOT::Append:0: RuntimeWarning: Replacing existing TH1: LCE (Potential memory leak).
# TROOT::Append:0: RuntimeWarning: Replacing existing TH1: EField (Potential memory leak).
# 99.720137812614979

# %% [markdown]
# <h1> LZ lim generation </h1>

# %%
def LZ_nom_lim(make_plot=True, mWimp = np.logspace(np.log10(6),np.log10(2000),30), f_drift=-1, Det='LZ',custom=False,\
               nom_ER_BG=6.3, nom_NR_BG=0.5, g1=0.075, eff_extract=0.95, \
               e_lifetime=850, nSim=1e5, mass_Fid=5600, livetime=1000, \
               S1_min=0, S2raw_min=450, E_min=0, S1_max=20, ER_max=100, nFold=3, name='LZ_FC_nom'):
    """
    #Generate the nominal LZ limit
    #Inputs ...
    # Array of WIMP masses, in units of GeV/c^2, logarithmically spaced
    # Drift field V/cm
    # nominal ER background = 1.5 events
    # nominal NR background = 0.4 events
    # g1
    # Extraction Eff
    # electron lifetime in micro seconds
    # drift distance at the center of the detector
    # number of events to simulate (50,000)
    # Fiducial mass in kg
    # livetime in days
    # Single photon resolution in PE
    # Single electron size in PE = 50
    # Single electron res in PE = 9.9
    # S2_min = 250 PHE ~ 5 electrons extracted
    # S1_min (S1 PE cut off) ~ 3 PE
    # num of electrons min (minimum number of electrons extracted)
    # E_min, the NR energy cut off, default to 3 KeVnr
    # Max S1 in search window, and when calculating acceptance from a flat NR BG
    # MAX E when simulating a flat NR spectrum to get acceptance
    """
    
    start_time = time.time()
    
    #E field [V/cm] and discrimination vs. g1 (0.04, 0.07, 0.10) ... from Matthew
    aa=np.array([50, 100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 2000])
    bb=np.array([0.0080, 0.0109, 0.0108, 0.0098, 0.0086, 0.0082, 0.0076, 0.0067, 0.0060, 0.0063, 0.0063, 0.0064])
    cc=np.array([0.0068, 0.0089, 0.0088, 0.0078, 0.0068, 0.0063, 0.0059, 0.0053, 0.0049, 0.0050, 0.0050, 0.0055])
    dd=np.array([0.0055, 0.0070, 0.0067, 0.0057, 0.0050, 0.0044, 0.0042, 0.0040, 0.0038, 0.0037, 0.0037, 0.0047])

    #Critical numbers for 5 and 3 sigma discovery with a fixed BG = 0.2
    #crit_BGs=np.array([0, 0.5, 1.0, 1.5, 1.9, 2.5, 5, 10, 20, 50])
    #crit_sig5=np.array([6, 9, 10, 12, 13, 15, 20, 30, 47, 90])
    #crit_sig3=np.array([3, 5, 6, 7, 8, 9, 14, 21, 35, 73])

    #With a sigma BG = 0.1 * BG
    crit_BGs=np.array([0, 0.25, 0.5, 1, 2, 5, 10, 20, 50])
    crit_sig3=np.array([1, 3, 4, 6, 8, 14, 22, 37, 79])
    crit_sig5=np.array([2, 6, 8, 10, 13, 21, 32, 50, 100])
        
    #With a sigma BG = 0.5 * BG
    #crit_BGs=np.array([0, 0.25, 0.5, 1, 2, 5, 10, 20, 50])
    #crit_sig3=np.array([1, 4,  5, 7, 10, 18, 32, 57, 133])
    #crit_sig5=np.array([2, 7, 9, 12, 17, 30, 49, 85, 192])

    sigAcc = np.empty_like(mWimp)
    accept = np.empty_like(mWimp)
    sigma_UL = np.empty_like(mWimp)
    Disc_Pot_sig3 = np.empty_like(mWimp) #Discovery Potential
    Disc_Pot_sig5 = np.empty_like(mWimp)
    #SE_res=np.sqrt(SE_size)/SE_size # single electron resolution of the PMT
    #ER_leak_corr_g1... interpolate leakage fraction table and normalize to leakage at 700V/cm and g1=0.07. Original BG calc
    #ER_leak_corr_g1=np.interp( g1, np.array([0.04, 0.07, 0.10]),np.array([np.interp(f_drift,aa,bb), np.interp(f_drift,aa,cc), np.interp(f_drift,aa,dd)]) )/cc[7]
    numBG_predict_list= [nom_NR_BG + nom_ER_BG] # NR + ER background
    nSig_90UL_sense_list = [np.sqrt(2.463*numBG_predict_list[0]+1.101) + 1.416]
    
    NEST =NEST_setup(Det=Det, f_drift=f_drift, nFold=nFold, g1=g1, eff_extract=eff_extract, \
                     e_lifetime=e_lifetime, custom=custom)
    S1_bin_cen_n, mean_S2oS1_n, std_S2oS1_n, S1_bin_cen_e, mean_S2oS1_e, std_S2oS1_e, E_bin_cen_e,\
    Eff_e, E_bin_cen_n, Eff_n,num_leak_e, num_total_e, leak_gauss_e, sNR = \
    genBands(NEST=NEST,S2raw_min=S2raw_min,nSim=1e6,mWmp=50)
    
    print("k = 0 of {:d}	Mass[GeV/c^2]	90%CL [cm^2]	3 sigma	 5 sigma".format(len(mWimp)))
    NEST.SetParticleType(0) #set NEST to NR for WIMPs
    #loop through WIMP masses
    for k, mWmp in enumerate(mWimp):
        #switch background prediction depending on mWmp at mass given by mWB8
        numBG_predict=numBG_predict_list[0]
        nSig_90UL_sense=nSig_90UL_sense_list[0]
        
        Nph, Ne, S1, S2, S1c, S2c, WmpRate, Det_exposure_factor=WIMP2NphNe(NEST=NEST,mWmp=mWmp,nSim=nSim,showFig=False)
        WS_cut=(S1c>0) & (S2>=S2raw_min)
        S1_cut=S1c[WS_cut]
        S2_cut=S2c[WS_cut]
        s1_range=inrange(S1_cut,[0.1,S1_max])
        cutSig = WS_cut
        accept[k]=sum(log10(S2_cut[s1_range]/S1_cut[s1_range]) < np.interp(S1_cut[s1_range],S1_bin_cen_n,mean_S2oS1_n))/len(S1_cut[s1_range])
        #sigAcc[k] = eff(cutSig)*(accept[k] ) #eff doesn't work in 2.7
        sigAcc[k] = (sum(cutSig) / len(cutSig)) * (accept[k]) #for some reason eff doesn't work with python2.7 ?
        nSig_obs_1e36 = WmpRate * sigAcc[k] * mass_Fid * livetime #WIMP rate is evts/kg/day/pb
        sigma_UL[k] = nSig_90UL_sense * (1e-36) / nSig_obs_1e36
        
        #Find Discovery Potential, 50% of the time at 3 and 5 sigma.
        ncrit_sig3=np.ceil(np.interp(numBG_predict,crit_BGs,crit_sig3))
        ncrit_sig5=np.ceil(np.interp(numBG_predict,crit_BGs,crit_sig5))
        S_crit=nSig_obs_1e36 / (1e-36) #scaling factor. N_events/Cross_Section
        Disc_Pot_sig3[k]=(ncrit_sig3-numBG_predict) / S_crit
        Disc_Pot_sig5[k]=(ncrit_sig5-numBG_predict) / S_crit
        
        print("k = {:d} of {:d}	{:.2f}	{:.2e}	{:.2e}	{:.2e}".format(k+1,len(mWimp),mWmp, sigma_UL[k], Disc_Pot_sig3[k], Disc_Pot_sig5[k]))

    if make_plot:
        #Make plot
        mpl.pyplot.figure();
        mpl.pyplot.clf()
        mpl.pyplot.hold('on')
        mpl.pyplot.loglog(mWimp,Disc_Pot_sig5 ,'-', linewidth=3,color='m')
        mpl.pyplot.loglog(mWimp,Disc_Pot_sig3 ,'--', linewidth=3,color='m')
        mpl.pyplot.loglog(mWimp, sigma_UL,'-', linewidth=3,color='b')
        #plot(mWimp, sigma_UL,'-', linewidth=3)
        #gca().set_xscale('log')
        #set(gca,'xscale','log')
        #gca().set_yscale('log')
        mpl.pyplot.grid('on')
        mpl.pyplot.minorticks_on()
        mpl.pyplot.xlabel('WIMP Mass [GeV/$c^2$]')
        mpl.pyplot.ylabel('WIMP-nucleon cross section [cm$^2$]')
        mpl.pyplot.xlim([5, 2e3])
        mpl.pyplot.legend(('5$\sigma$ median significance','3$\sigma$ median significance','90$\%$ CL'))
        mpl.pyplot.ylim([1e-48, 1e-45])
        mpl.pyplot.grid(which='minor')
        mpl.pyplot.savefig('figs/'+name+'.png',dpi=150)
    
    np.savetxt('data/'+name+'_90CL_lim.txt', np.transpose([mWimp, sigma_UL]), delimiter='\t')
    np.savetxt('data/'+name+'_disc_sig3.txt', np.transpose([mWimp, Disc_Pot_sig3]), delimiter='\t')
    np.savetxt('data/'+name+'_disc_sig5.txt', np.transpose([mWimp, Disc_Pot_sig5]), delimiter='\t')
    
    print ("Time elapsed (seconds) = {:f}".format( time.time() - start_time ))
    
    return True

# %% [markdown]
# <h1> Run the code for LZ limit generation </h1>

# %%
LZ_nom_lim(name='LZ_nom_FC_discrim300',nom_ER_BG=6.3*2/3,S1_max=20,mWimp = np.logspace(np.log10(3),np.log10(2000),30),nSim=2e6)
# Out:
# k = 0 of 30	Mass[GeV/c^2]	90%CL [cm^2]	3 sigma	 5 sigma
# total rate above 0.00 keV = 381034 [evts/kg/day per pb]
# Detector exposure factor per pb = 9.37298e-07
# k = 1 of 30	3.00	2.33e-42	4.36e-42	7.64e-42
# total rate above 0.00 keV = 425663 [evts/kg/day per pb]
# Detector exposure factor per pb = 8.39027e-07
# k = 2 of 30	3.75	2.78e-43	5.20e-43	9.12e-43
# total rate above 0.00 keV = 480993 [evts/kg/day per pb]
# Detector exposure factor per pb = 7.42512e-07
# k = 3 of 30	4.70	2.37e-44	4.43e-44	7.76e-44
# total rate above 0.00 keV = 547751 [evts/kg/day per pb]
# Detector exposure factor per pb = 6.52017e-07
# k = 4 of 30	5.88	2.79e-45	5.21e-45	9.13e-45
# total rate above 0.00 keV = 626063 [evts/kg/day per pb]
# Detector exposure factor per pb = 5.70458e-07
# k = 5 of 30	7.36	4.58e-46	8.56e-46	1.50e-45
# total rate above 0.00 keV = 714881 [evts/kg/day per pb]
# Detector exposure factor per pb = 4.99583e-07
# k = 6 of 30	9.20	9.67e-47	1.81e-46	3.17e-46
# total rate above 0.00 keV = 811223 [evts/kg/day per pb]
# Detector exposure factor per pb = 4.40252e-07
# k = 7 of 30	11.52	2.93e-47	5.47e-47	9.59e-47
# total rate above 0.00 keV = 909334 [evts/kg/day per pb]
# Detector exposure factor per pb = 3.92752e-07
# k = 8 of 30	14.41	1.24e-47	2.32e-47	4.07e-47
# total rate above 0.00 keV = 1.00014e+06 [evts/kg/day per pb]
# Detector exposure factor per pb = 3.57093e-07
# k = 9 of 30	18.04	7.01e-48	1.31e-47	2.30e-47
# total rate above 0.00 keV = 1.07165e+06 [evts/kg/day per pb]
# Detector exposure factor per pb = 3.33264e-07
# k = 10 of 30	22.57	4.81e-48	8.99e-48	1.57e-47
# total rate above 0.00 keV = 1.11109e+06 [evts/kg/day per pb]
# Detector exposure factor per pb = 3.21436e-07
# k = 11 of 30	28.24	3.82e-48	7.14e-48	1.25e-47
# total rate above 0.00 keV = 1.10877e+06 [evts/kg/day per pb]
# Detector exposure factor per pb = 3.22106e-07
# k = 12 of 30	35.34	3.42e-48	6.39e-48	1.12e-47
# total rate above 0.00 keV = 1.06241e+06 [evts/kg/day per pb]
# Detector exposure factor per pb = 3.36163e-07
# k = 13 of 30	44.22	3.30e-48	6.16e-48	1.08e-47
# total rate above 0.00 keV = 978733 [evts/kg/day per pb]
# Detector exposure factor per pb = 3.64903e-07
# k = 14 of 30	55.34	3.42e-48	6.40e-48	1.12e-47
# total rate above 0.00 keV = 870960 [evts/kg/day per pb]
# Detector exposure factor per pb = 4.10056e-07
# k = 15 of 30	69.24	3.73e-48	6.98e-48	1.22e-47
# total rate above 0.00 keV = 753613 [evts/kg/day per pb]
# Detector exposure factor per pb = 4.73908e-07
# k = 16 of 30	86.65	4.22e-48	7.89e-48	1.38e-47
# total rate above 0.00 keV = 638288 [evts/kg/day per pb]
# Detector exposure factor per pb = 5.59533e-07
# k = 17 of 30	108.43	4.94e-48	9.23e-48	1.62e-47
# total rate above 0.00 keV = 532194 [evts/kg/day per pb]
# Detector exposure factor per pb = 6.71076e-07
# k = 18 of 30	135.68	5.89e-48	1.10e-47	1.93e-47
# total rate above 0.00 keV = 438737 [evts/kg/day per pb]
# Detector exposure factor per pb = 8.14025e-07
# k = 19 of 30	169.78	7.12e-48	1.33e-47	2.33e-47
# total rate above 0.00 keV = 358756 [evts/kg/day per pb]
# Detector exposure factor per pb = 9.95503e-07
# k = 20 of 30	212.46	8.71e-48	1.63e-47	2.85e-47
# total rate above 0.00 keV = 291635 [evts/kg/day per pb]
# Detector exposure factor per pb = 1.22462e-06
# k = 21 of 30	265.85	1.07e-47	2.00e-47	3.50e-47
# total rate above 0.00 keV = 236063 [evts/kg/day per pb]
# Detector exposure factor per pb = 1.51291e-06
# k = 22 of 30	332.68	1.32e-47	2.47e-47	4.32e-47
# total rate above 0.00 keV = 190483 [evts/kg/day per pb]
# Detector exposure factor per pb = 1.87494e-06
# k = 23 of 30	416.29	1.64e-47	3.06e-47	5.36e-47
# total rate above 0.00 keV = 153349 [evts/kg/day per pb]
# Detector exposure factor per pb = 2.32895e-06
# k = 24 of 30	520.92	2.04e-47	3.81e-47	6.67e-47
# total rate above 0.00 keV = 123243 [evts/kg/day per pb]
# Detector exposure factor per pb = 2.89788e-06
# k = 25 of 30	651.85	2.54e-47	4.75e-47	8.32e-47
# total rate above 0.00 keV = 98920 [evts/kg/day per pb]
# Detector exposure factor per pb = 3.61042e-06
# k = 26 of 30	815.69	3.16e-47	5.90e-47	1.03e-46
# total rate above 0.00 keV = 79319.4 [evts/kg/day per pb]
# Detector exposure factor per pb = 4.50259e-06
# k = 27 of 30	1020.71	3.95e-47	7.38e-47	1.29e-46
# total rate above 0.00 keV = 63555.1 [evts/kg/day per pb]
# Detector exposure factor per pb = 5.61942e-06
# k = 28 of 30	1277.26	4.94e-47	9.24e-47	1.62e-46
# total rate above 0.00 keV = 50894.8 [evts/kg/day per pb]
# Detector exposure factor per pb = 7.01727e-06
# k = 29 of 30	1598.28	6.19e-47	1.16e-46	2.03e-46
# total rate above 0.00 keV = 40738.5 [evts/kg/day per pb]
# Detector exposure factor per pb = 8.76671e-06
# k = 30 of 30	2000.00	7.70e-47	1.44e-46	2.52e-46
# Time elapsed (seconds) = 644.651111
# TROOT::Append:0: RuntimeWarning: Replacing existing TH1: LCE (Potential memory leak).
# TROOT::Append:0: RuntimeWarning: Replacing existing TH1: EField (Potential memory leak).
# True

# %% [markdown]
# <h1> Run LUX Limit </h1>

# %%
LZ_nom_lim(name='LUX',mWimp = np.logspace(np.log10(5),np.log10(2000),30), \
           nom_ER_BG=0, nom_NR_BG=0,S1_max=50,custom=False,mass_Fid=150, livetime=100,S2raw_min=150)
# Out:
# k = 0 of 30	Mass[GeV/c^2]	90%CL [cm^2]	3 sigma	 5 sigma
# total rate above 0.00 keV = 498396 [evts/kg/day per pb]
# Detector exposure factor per pb = 3.58292e-08
# k = 1 of 30	5.00	8.04e-43	3.26e-43	6.52e-43
# total rate above 0.00 keV = 562479 [evts/kg/day per pb]
# Detector exposure factor per pb = 3.17472e-08
# k = 2 of 30	6.15	2.48e-43	1.00e-43	2.01e-43
# total rate above 0.00 keV = 636291 [evts/kg/day per pb]
# Detector exposure factor per pb = 2.80644e-08
# k = 3 of 30	7.56	5.36e-44	2.17e-44	4.35e-44
# total rate above 0.00 keV = 718858 [evts/kg/day per pb]
# Detector exposure factor per pb = 2.4841e-08
# k = 4 of 30	9.29	1.51e-44	6.11e-45	1.22e-44
# total rate above 0.00 keV = 807677 [evts/kg/day per pb]
# Detector exposure factor per pb = 2.21093e-08
# k = 5 of 30	11.43	5.32e-45	2.16e-45	4.31e-45
# total rate above 0.00 keV = 898264 [evts/kg/day per pb]
# Detector exposure factor per pb = 1.98796e-08
# k = 6 of 30	14.05	2.47e-45	1.00e-45	2.00e-45
# total rate above 0.00 keV = 983701 [evts/kg/day per pb]
# Detector exposure factor per pb = 1.8153e-08
# k = 7 of 30	17.27	1.43e-45	5.79e-46	1.16e-45
# total rate above 0.00 keV = 1.05488e+06 [evts/kg/day per pb]
# Detector exposure factor per pb = 1.69282e-08
# k = 8 of 30	21.24	9.66e-46	3.92e-46	7.84e-46
# total rate above 0.00 keV = 1.10164e+06 [evts/kg/day per pb]
# Detector exposure factor per pb = 1.62095e-08
# k = 9 of 30	26.11	7.58e-46	3.07e-46	6.15e-46
# total rate above 0.00 keV = 1.11523e+06 [evts/kg/day per pb]
# Detector exposure factor per pb = 1.6012e-08
# k = 10 of 30	32.10	6.52e-46	2.65e-46	5.29e-46
# total rate above 0.00 keV = 1.09121e+06 [evts/kg/day per pb]
# Detector exposure factor per pb = 1.63645e-08
# k = 11 of 30	39.47	6.19e-46	2.51e-46	5.02e-46
# total rate above 0.00 keV = 1.03161e+06 [evts/kg/day per pb]
# Detector exposure factor per pb = 1.731e-08
# k = 12 of 30	48.52	6.20e-46	2.51e-46	5.03e-46
# total rate above 0.00 keV = 944498 [evts/kg/day per pb]
# Detector exposure factor per pb = 1.89065e-08
# k = 13 of 30	59.66	6.55e-46	2.66e-46	5.31e-46
# total rate above 0.00 keV = 841181 [evts/kg/day per pb]
# Detector exposure factor per pb = 2.12286e-08
# k = 14 of 30	73.35	7.20e-46	2.92e-46	5.84e-46
# total rate above 0.00 keV = 732624 [evts/kg/day per pb]
# Detector exposure factor per pb = 2.43742e-08
# k = 15 of 30	90.19	8.08e-46	3.28e-46	6.56e-46
# total rate above 0.00 keV = 627196 [evts/kg/day per pb]
# Detector exposure factor per pb = 2.84714e-08
# k = 16 of 30	110.88	9.41e-46	3.82e-46	7.63e-46
# total rate above 0.00 keV = 530057 [evts/kg/day per pb]
# Detector exposure factor per pb = 3.36891e-08
# k = 17 of 30	136.33	1.10e-45	4.45e-46	8.90e-46
# total rate above 0.00 keV = 443718 [evts/kg/day per pb]
# Detector exposure factor per pb = 4.02444e-08
# k = 18 of 30	167.62	1.31e-45	5.31e-46	1.06e-45
# total rate above 0.00 keV = 368835 [evts/kg/day per pb]
# Detector exposure factor per pb = 4.8415e-08
# k = 19 of 30	206.08	1.58e-45	6.39e-46	1.28e-45
# total rate above 0.00 keV = 305003 [evts/kg/day per pb]
# Detector exposure factor per pb = 5.85475e-08
# k = 20 of 30	253.38	1.93e-45	7.81e-46	1.56e-45
# total rate above 0.00 keV = 251232 [evts/kg/day per pb]
# Detector exposure factor per pb = 7.10782e-08
# k = 21 of 30	311.53	2.31e-45	9.35e-46	1.87e-45
# total rate above 0.00 keV = 206349 [evts/kg/day per pb]
# Detector exposure factor per pb = 8.65386e-08
# k = 22 of 30	383.02	2.84e-45	1.15e-45	2.30e-45
# total rate above 0.00 keV = 169109 [evts/kg/day per pb]
# Detector exposure factor per pb = 1.05595e-07
# k = 23 of 30	470.92	3.44e-45	1.39e-45	2.79e-45
# total rate above 0.00 keV = 138361 [evts/kg/day per pb]
# Detector exposure factor per pb = 1.29062e-07
# k = 24 of 30	578.99	4.22e-45	1.71e-45	3.42e-45
# total rate above 0.00 keV = 113062 [evts/kg/day per pb]
# Detector exposure factor per pb = 1.57941e-07
# k = 25 of 30	711.87	5.21e-45	2.11e-45	4.23e-45
# total rate above 0.00 keV = 92296.2 [evts/kg/day per pb]
# Detector exposure factor per pb = 1.93476e-07
# k = 26 of 30	875.24	6.38e-45	2.59e-45	5.17e-45
# total rate above 0.00 keV = 75287.8 [evts/kg/day per pb]
# Detector exposure factor per pb = 2.37185e-07
# k = 27 of 30	1076.10	7.81e-45	3.17e-45	6.34e-45
# total rate above 0.00 keV = 61376.3 [evts/kg/day per pb]
# Detector exposure factor per pb = 2.90945e-07
# k = 28 of 30	1323.05	9.59e-45	3.89e-45	7.78e-45
# total rate above 0.00 keV = 50012 [evts/kg/day per pb]
# Detector exposure factor per pb = 3.57057e-07
# k = 29 of 30	1626.69	1.19e-44	4.81e-45	9.62e-45
# total rate above 0.00 keV = 40737.9 [evts/kg/day per pb]
# Detector exposure factor per pb = 4.38342e-07
# k = 30 of 30	2000.00	1.45e-44	5.86e-45	1.17e-44
# Time elapsed (seconds) = 63.486335
# TROOT::Append:0: RuntimeWarning: Replacing existing TH1: LCE (Potential memory leak).
# TROOT::Append:0: RuntimeWarning: Replacing existing TH1: EField (Potential memory leak).
# True
